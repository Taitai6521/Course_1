# %% [markdown]
# # 1.  変数の割り当て

# %%
# "portfolio_1 "という変数を定義し、数値（integer）を割り当てる。
# 整数とは、正または負の整数である（小数点以下は含まない）。

ポートフォリオ_1 = 5000

# %%
# "portfolio_1 "を見てみよう
portfolio_1
# Out:
# 5000

# %%
# "portfolio_2 "という変数を定義し，数値（float）を代入する．
# フロートは，整数部と小数部を分ける小数点を持つ実数である

portfolio_2 = 2000.5

# %%
# "portfolio_2 "を表示してみましょう
portfolio_2
# Out:
# 2000.5

# %%
# "portfolio_2 "を上書きしてみましょう (ポートフォリオの値が増えたと仮定します)
portfolio_2 = 3000.5

# %%
# "portfolio_2 "には最新の値しか含まれていないことに注意してください
portfolio_2
# Out:
# 3000.5

# %%
# "portfolio_1 "の型を取得します それはintegerです
# 整数は，正または負の整数（小数点以下は含まない）である
type(portfolio_1)
# Out:
# int

# %%
# "portfolio_2 "の型を取得します（float）．
# float は，整数部と小数部を分ける小数点を持つ実数です．
type(portfolio_2)
# Out:
# float

# %% [markdown]
# **ミニチャレンジ#1:**
# - **変数AMZN（Amazonのティッカーシンボル）を定義し、以下の3つの値を割り当てました。コードセルを実行せずに、これらのコードラインは何を生成しますか？
# - **コードセルを実行して、答えを確認してください**。
#
#
#
# ```
# AMZN = 3324
# AMZN = 3400
# AMZN = 3530
# AMZN
# ```

# %% [markdown]
# **ミニチャレンジ #2:**
# - **変数AAPL（Apple株のティッカーシンボル）を定義し、以下の2つの値を代入しました。何のコードセルも実行せずに、これらのコードラインは何を生成するでしょうか？
# - **コードセルを実行して、答えを確認してください**。
#
#
#
# ```
# AAPL = 112
# AAPL = 115.3
# type(AAPL)
# ```

# %% [markdown]
# # 2. 数学演算

# %%
# AAPLという変数を定義し、5つの銘柄を持っていることを示す5で初期化します。
# ♪追加で株を買ったとすると 5株ではなく6株になります 
# AAPLを1株増やすには次のようにします。
AAPL = 5
AAPL = 5 # AAPL = AAPL + 1 
AAPL
# Out:
# 6

# %%
AAPL = 5 AAPL + 1 AAPL # 代わりに、次のように変数AAPLを1つ増やすことができます。
AAPL = 5
AAPL += 1 
AAPL
# Out:
# 6

# %%
# AAPL株の価格が260ドルで、現在ポートフォリオに5つのAAPL株があるとすると
# ポートフォリオの総価値（口座残高）を次のように計算できます。
AAPL_count = 5
AAPL_price = 260
account_balance = AAPL_count * AAPL_price
account_balance
# Out:
# 1300

# %%
# ♪口座に20000ドルあるとしよう
# この総額でAMZNの株を買いたいと思います 
# AMZN株の価格は、それぞれ3116ドルです

アカウント_バランス = 20000
アカウント_バランス
# Out:
# 20000

# %%
# 口座残高をアマゾン株の価格で割り、答えを単位にする
AMZN_price = 3116 
units = account_balance/AMZN_price
単位
# Out:
# 6.418485237483954

# %% [markdown]
# **ミニチャレンジ #3:**
# - 15個のGoogle株（ステッカーシンボル：GOOG）をそれぞれ1500円で所有していると仮定して、ポートフォリオの総価値を計算するコードを書いてください。

# %% [markdown]
# **ミニチャレンジ #4:**
# - **Google (GOOG)の株価を2日間で取得し、リターンを計算するコードを書いてください。
#   - **GOOGの1日目の価格＝260ドル**。
#   - **GOOGの2日目の価格 = ˶ˆ꒳ˆ˵ )

# %% [markdown]
# # 3. 演算順序（優先順位）について

# %%
# 3と4を足して、5を掛ける
# 括弧が最も高い優先順位を持つことに注意
(3 + 4) * 5
# Out:
# 35

# %%
# 足し算に比べて掛け算の方が優先順位が高い
1 + 2 * 3
# Out:
# 7

# %%
# 割り算は足し算に比べて優先順位が高い
16 / 4 + 25 / 5
# Out:
# 9.0

# %% [markdown]
# **ミニチャレンジ #5:**
# - AAPLの株式を15株所有していると仮定します。アップル社が優れた機能を持つ5つの新製品の発売を発表したため、株価は1株170ドルに上昇しました。合計利益を計算してください。

# %% [markdown]
# **ミニチャレンジ #6:**
# - z = |x - y| * (x + y)** ** 次の数学的操作を行うコードを書いてください。

# %% [markdown]
# # 4. プリント操作

# %%
# Print関数は画面上に要素を表示するために使われる
# 文字列の定義 x 
# Pythonの文字列は文字の並びである
# Pythonの文字列はシングルまたはダブルクォーテーションマークで囲まれる
x = "ファイナンスコースのパイソンへようこそ"

# %%
# 'x'のデータ型を取得する
type(x)
# Out:
# str

# %%
# xを印刷する
print(x)
# Out:
# Welcome to Python for Finance course

# %%
# 文字列を定義し、その中に'Apple Inc.
company_name = "Apple Inc."

# %%
# format()メソッドは、指定された値を整形し、プレースホルダーに挿入します。
# プレースホルダーは中括弧で定義します。{}
print("Ticker name for {} is AAPL".format(company_name))
# Out:
# Ticker name for Apple Inc. is AAPL

# %%
shares = 30

# %%
# print関数では、複数のプレースホルダーを配置することができます。
print("私は {} の {} 株を所有しています".format(sharts, company_name))
# Out:
# I own 30 shares of Apple Inc.

# %% [markdown]
# **ミニチャレンジ #7:**
# - **上記の文をAAPLのティッカーと一緒に出力するコードを書いてください**。
# - **i.e.: Apple Inc.(AAPL)の株式を30株所有しています**。

# %% [markdown]
# # 5. ユーザー入力の取得

# %%
# input は python の組み込み関数です。
# 銀行の顧客名を入力として取得し、画面に表示する 
name = input("Welcome to the bank, What's your name: ")
print('Hello', name)
# Out:
# Welcome to the bank, What's your name: Ryan
# Hello Ryan

# %%
# 銀行顧客の名前、年齢、資産などのデータを取得し、画面に表示します。
name = input("Welcome to the bank, please enter your name: ")
age = input("Enter your age: ")
networth = input("資産から負債を差し引いた正味財産を入力してください。")
print("My name is {}, I am {} years, and my estimated networth is = {}".format(name, age, networth))
# Out:
# Welcome to the bank, please enter your name: ryan
# Enter your age: 32
# Enter your total networth (assets - liabilities): 3000
# My name is ryan, I am 32 years old, and my estimated networth is = 3000

# %%
# ユーザーの入力を得て，数学的な演算を行い，その結果を表示する 
# Note: エラーが出ていませんか？次のコードセルに移動します 
x = input("Enter the price of AAPL stock today: ")
y = input("Enter the number of APPLE stock that you want to buy: ")
print('AAPL株を{}株、{}ドルで購入するのに必要な資金の合計は{}'.format(y, x, x*y))
# Out:
# Enter the price of AAPL stock today: 3000
# Enter the number of APPLE stocks that you want to buy: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-8ad23f4fd66e> in <module>()
#       3 x = input("Enter the price of AAPL stock today: ")
#       4 y = input("Enter the number of APPLE stocks that you want to buy: ")
# ----> 5 print('The total funds required to buy {} shares of AAPL stock at {} price is {}'.format(y, x, x*y))
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# 加算を行う前に、文字列データ型から整数データ型に変換する

x = input("Enter the price of AAPL stock today: ")
x = int(x)
y = 入力("購入したいAPPLE株の数を入力してください: ")
y = int(y)
print('AAPL株を{}株、{}ドルで購入するために必要な資金総額は{}'.format(y, x, x*y))
# Out:
# Enter the price of AAPL stock today: 3000
# Enter the number of APPLE stocks that you want to buy: 5
# The total funds required to buy 5 shares of AAPL stock at 3000 price is 15000

# %% [markdown]
# **ミニチャレンジ#8:**
# - **銘柄名、販売価格、所有したい銘柄数を入力し、この銘柄を購入するために必要な総資金を出力するコードを作成してください。予想される出力のサンプルを以下に示します。
#
#   - 購入したい銘柄の価格を入力してください。3000
#   - 買いたい株の数を入力してください。5
#   - 買いたい銘柄の名前を入力してください。AMZN
#   - 3000で5銘柄のAMZNを購入するために必要な資金の合計は15000です。

# %% [markdown]
# # excellent job

# %% [markdown]
# # mini challenges solutions

# %% [markdown]
# **ミニチャレンジ#1:**
# - 変数AMZN（Amazon株のティッカーシンボル）を定義し、以下の3つの値を割り当てました。どんなコードセルも実行せずに、これらのコードラインは何を生成しますか？
# - **コードセルを実行して、答えを確認してください**。
#
# ```
# AMZN = 3324
# AMZN = 3400
# AMZN = 3530
# AMZN
# ```

# %%
# このコードの出力は 3530
# 最初は3324をAMZNに入れ、次に3400をAMZNに入れて上書きし、次に3530をAMZNに入れる
AMZN = 3324
AMZN = 3400
AMZN = 3530
AMZN
# Out:
# 3530

# %% [markdown]
# **ミニ・チャレンジ2
# - **変数AAPL（Apple株のティッカーシンボル）を定義し、以下の2つの値を代入しました。コードセルを実行せずに、これらのコードラインは何を生成しますか？
# - **コードセルを実行して、答えを確認してください**。
#
#
#
#
# ```
# AAPL = 112
# AAPL = 115.3
# type(AAPL)
# ```

# %%
AAPL = 112
AAPL = 115.3
type(AAPL)
# Out:
# float

# %% [markdown]
# **ミニチャレンジ#3の解答:**
# - 15個のGoogle株（ステッカーシンボル：GOOG）をそれぞれ1500円で所有していると仮定して、ポートフォリオの総価値を計算するコードを書いてください。

# %%
price  = 1500
x  = 15
amount = x * price
amount
# Out:
# 22500

# %% [markdown]
# **ミニチャレンジ #4 解決策： **
# - Google (GOOG)の株価を2日分取り込んで、リターンを計算するコードを書いてください。
#   - **GOOGの1日目の価格＝260ドル**。
#   - **2日目のGOOG価格 = ˶ˆ꒳ˆ˵ )

# %%
GOOG_price_1 = 260
GOOG_price_2 = 280

price_diff = GOOG_price_2 - GOOG_price_1
percentage_change = price_diff / GOOG_price_1 * 100

percentage_change
# Out:
# 7.6923076923076925

# %% [markdown]
# **ミニチャレンジ #5 解決策： **
# - **1株150ドルのAAPL株を15株所有していると仮定します。Appleは優れた機能を持つ5つの新製品の発売を発表したため、株価は1株170ドルに上昇しました。利益の合計を計算してください。

# %%
AAPL_new = 170
AAPL_old = 150
num_shares = 15
profit = (AAPL_new - AAPL_old) * num_shares   
profit
# Out:
# 300

# %% [markdown]
# **ミニチャレンジ#6の解答:**
# - z = |x - y| * (x + y)** 以下の数学的操作を行うコードを書いてください。

# %%
x = 4
y = 2
z = abs(x-y) * (x+y)

# %% [markdown]
# **ミニチャレンジ#7の解答:**
# - AAPLのティッカーと一緒に上記の文をプリントアウトするコードを書いてください。
# - **i.e.: Apple Inc.(AAPL)の株を30株持っています**。

# %%
ticker = 'AAPL'
print("I own {} shares of {}({})".format( shares, company_name, ticker))
# Out:
# I own 30 shares of Apple Inc.(AAPL)

# %% [markdown]
# **ミニチャレンジ #8 解決策： **
# - **銘柄名、販売価格、所有したい銘柄数を入力し、この銘柄を購入するために必要な総資金を出力するコードを作成してください。予想される出力のサンプルを以下に示します。
#
#   - 購入したい銘柄の価格を入力してください。3000
#   - 買いたい株の数を入力してください。5
#   - 買いたい銘柄の名前を入力してください。AMZN
#   - 3000で5銘柄のAMZNを買うために必要な資金は15000です。

# %%
x = input("買いたい株の価格を入力してください：")
x = int(x)
y = 入力("買いたい株の数を入力してください: ")
y = int(y)
z = 入力("購入したい銘柄の名前を入力してください。")
print('｛｝個の｛｝銘柄を｛｝で買うために必要な資金総額は｛｝です'.format(y,z,x, x*y))
# Out:
# Enter the price of the stock you want to buy: 3000
# Enter the number of stocks that you want to buy: 5
# Enter the name of the stock that you want to buy: AMZN
# The total funds required to buy 5 number of AMZN stocks at 3000 is 15000
